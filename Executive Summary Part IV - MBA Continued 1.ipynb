# %%
# Data processing
import pandas as pd
import numpy as np
# Data visualization
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import make_blobs
import seaborn as sns
# Model and performance
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBClassifier
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.feature_selection import RFECV 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.inspection import permutation_importance
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy.cluster.hierarchy as shc
import itertools
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
item_list = pd.read_csv('item_list.csv', delimiter = '\t', header = None)
item_list0 = pd.read_csv('item_list0.csv', delimiter = '\t', header = None)
item_list1 = pd.read_csv('item_list1.csv', delimiter = '\t', header = None)
item_list2 = pd.read_csv('item_list2.csv', delimiter = '\t', header = None)

# %%
#Converting Data Frame into Array for TransactionEncoder
item_list_array = item_list.values
item_list_array
# Out:
# array([["['Blood Oranges']"],
#        ["['Organic Low Fat Chocolate Milk']"],
#        ["['Organic Baby Spinach']"],
#        ...,
#        ["['Dha Omega 3 Vitamin D Milk']"],
#        ["['Creme Fraiche French Cultured Cream']"],
#        ["['Applewood Smoked Turkey Breast']"]], dtype=object)

# %%
#Converting Data Frame into Array for TransactionEncoder
item_list0_array = item_list0.values
item_list0_array
# Out:
# array([["['Organic Blackberries']"],
#        ["['Original Turkey Jerky']"],
#        ["['Organic Yellow Onion']"],
#        ...,
#        ["['Kosher Dill Pickles']"],
#        ["['Blackberry Cucumber Sparkling Water']"],
#        ["['Creme Fraiche French Cultured Cream']"]], dtype=object)

# %%
#Converting Data Frame into Array for TransactionEncoder
item_list1_array = item_list1.values
item_list1_array
# Out:
# array([["['Blood Oranges']"],
#        ["['Organic Low Fat Chocolate Milk']"],
#        ["['Organic Baby Spinach']"],
#        ...,
#        ["['Bag of Organic Bananas']"],
#        ["['Pure Irish Butter']"],
#        ["['Oatmeal Dark Chocolate Cookies']"]], dtype=object)

# %%
#Converting Data Frame into Array for TransactionEncoder
item_list2_array = item_list2.values
item_list2_array
# Out:
# array([["['Sustainably Soft Bath Tissue']"],
#        ["['Seedless Cucumbers']"],
#        ["['Organic Garnet Sweet Potato (Yam)']"],
#        ...,
#        ["['Egg White Patties']"],
#        ["['Dha Omega 3 Vitamin D Milk']"],
#        ["['Applewood Smoked Turkey Breast']"]], dtype=object)

# %%
#Performing and fitting TransactionEncoder creating one-hot-encoding for frequent itemsets for all the clusters
te = TransactionEncoder()
te_array = te.fit_transform(item_list_array)
te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Performing and fitting TransactionEncoder creating one-hot-encoding for frequent itemsets for Cluster 0
te = TransactionEncoder()
te_array0 = te.fit_transform(item_list0_array)
te_array0
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Performing and fitting TransactionEncoder creating one-hot-encoding for frequent itemsets for Cluster 1
te = TransactionEncoder()
te_array1 = te.fit_transform(item_list1_array)
te_array1
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Performing and fitting TransactionEncoder creating one-hot-encoding for frequent itemsets for Cluster 2
te = TransactionEncoder()
te_array2 = te.fit_transform(item_list2_array)
te_array2
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Converting the TransactionEncoder one-hot-encoded data into DataFrame for all Clustered items
item_df = pd.DataFrame(te_array, columns=te.columns_)

item_df
# Out:
#        ["100% Natural America's Favorite Tea"]  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 69531                                    False
# 69532                                    False
# 69533                                    False
# 69534                                    False
# 69535                                    False
#
#        ["Affi's Aubergine Fire Roasted Eggplant & Garlic All Natural Dip"]  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...

# %%
#Converting the TransactionEncoder one-hot-encoded data into DataFrame for Cluster 0 items
item_df0 = pd.DataFrame(te_array0, columns=te.columns_)

item_df0
# Out:
#        ["Affi's Aubergine Fire Roasted Eggplant & Garlic All Natural Dip"]  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 16782                                              False
# 16783                                              False
# 16784                                              False
# 16785                                              False
# 16786                                              False
#
#        ["Annie's Bunny Fruit Snacks Variety"]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# ...

# %%
#Converting the TransactionEncoder one-hot-encoded data into DataFrame for Cluster 1 items
item_df1 = pd.DataFrame(te_array1, columns=te.columns_)

item_df1
# Out:
#        ["Annie's Bunny Fruit Snacks Variety"]  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 26667                                   False
# 26668                                   False
# 26669                                   False
# 26670                                   False
# 26671                                   False
#
#        ["Annie's® Homegrown Gluten Free Double Chocolate Chip Granola"]  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...

# %%
#Converting the TransactionEncoder one-hot-encoded data into DataFrame for Cluster 2 items
item_df2 = pd.DataFrame(te_array2, columns=te.columns_)

item_df2
# Out:
#        ["100% Natural America's Favorite Tea"]  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 26072                                    False
# 26073                                    False
# 26074                                    False
# 26075                                    False
# 26076                                    False
#
#        ["Affi's Aubergine Fire Roasted Eggplant & Garlic All Natural Dip"]  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...

# %%
#Saving DataFrames to file
item_df.to_csv(r'C:\Users\p-mir\MS Data Science\Big Data Technologies\Final\item_df.csv', index=False)
item_df0.to_csv(r'C:\Users\p-mir\MS Data Science\Big Data Technologies\Final\item_df0.csv', index=False)
item_df1.to_csv(r'C:\Users\p-mir\MS Data Science\Big Data Technologies\Final\item_df1.csv', index=False)
item_df2.to_csv(r'C:\Users\p-mir\MS Data Science\Big Data Technologies\Final\item_df2.csv', index=False)
